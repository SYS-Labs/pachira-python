# %%
import json
import time
from pachira import *

# %%
abi = ABILoad(Platform.UNIV3, JSONContract.UniswapV3Pool)

# %% [markdown]
# ### (1) Extract Mint Events

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 15

# %%
dict_events = rEvents.apply(EventType.MINT, start_block=start_block, end_block=last_block)
# Out:
# mint at block:61,391,495 tx:0xa6bd1953b17041eeb0128b39a20f87afbb072e75b935d4550991a3ebc184d2f7
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#      chain       contract  type    platform  \
# 0  polygon  uniswapv3pool  mint  uniswap_v3
#
#                                  pool_address  \
# 0  0x4646e8a5e1d14e2da01577822d6346c7883c6890
#
#                                              tx_hash   blk_num   timestamp  \
# 0  0xa6bd1953b17041eeb0128b39a20f87afbb072e75b935...  61391495  1725402117
#
#                                              details
# 0  {'web3_type': <class 'web3._utils.datatypes.Mi...

# %% [markdown]
# ### (2) Extract Swap Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 3

# %%
dict_events = rEvents.apply(EventType.SWAP, start_block=start_block, end_block=last_block)
# Out:
# swap at block:61,391,507 tx:0xca666c287f1e1f2e1f1e766290ce0193bbf50ae51e1ee3dda21eba6931d13118
# swap at block:61,391,507 tx:0x7a01a24c29373cb01ff6ac20c5e21d4e3c8e592c17490cf1520b1e8250c63e1f
# swap at block:61,391,508 tx:0x43ccc5e3205535ea03ace347c2b4cf1b0e89b4dda1b010e77662db956ca5eb7d
# swap at block:61,391,508 tx:0x7760e06684606fe1ccae02b353e6645f15b0bbfa3dba81d44177dddee005d23a
# swap at block:61,391,508 tx:0x7abda0b7071af7696e2effc703c665375bb77f674ee2d89f0de9a25657505b7b
# swap at block:61,391,510 tx:0x37e64c072f4e0c43c55b71ea691ae9b8afb91ff8e90f134ec14a1eebd63509fd
# swap at block:61,391,510 tx:0x2037ebc07b9ae422bc9d25cce69b5e0abeb2b7b02224750bcd44997b77ff38a3
# swap at block:61,391,510 tx:0x6451a745eb6583272d3244b5fc690b8d461f8432d3c9ef30449ee098a213da6e
# swap at block:61,391,510 tx:0x39aff3a1b41e82b5fc62d44d76c47143ffc940c6d554a0b69b04a379ca168095
# swap at block:61,391,510 tx:0x98990115e4e7781138cbe85b50164ffd9d5a8d77d83be2eca04582ff205d6e9e
# swap at block:61,391,510 tx:0x4f61521a3082a52981e47632285aca29bf9e2fa89dd8b5e8a07023ab54e0bd44
# swap at block:61,391,510 tx:0x708b3c14f149738c7e113dad4b9cf4fed485e8690eb4e5092e4464174fbc6530
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#       chain       contract  type    platform  \
# 0   polygon  uniswapv3pool  swap  uniswap_v3
# 1   polygon  uniswapv3pool  swap  uniswap_v3
# 2   polygon  uniswapv3pool  swap  uniswap_v3
# 3   polygon  uniswapv3pool  swap  uniswap_v3
# 4   polygon  uniswapv3pool  swap  uniswap_v3
# 5   polygon  uniswapv3pool  swap  uniswap_v3
# 6   polygon  uniswapv3pool  swap  uniswap_v3
# 7   polygon  uniswapv3pool  swap  uniswap_v3
# 8   polygon  uniswapv3pool  swap  uniswap_v3
# 9   polygon  uniswapv3pool  swap  uniswap_v3
# 10  polygon  uniswapv3pool  swap  uniswap_v3
# 11  polygon  uniswapv3pool  swap  uniswap_v3
#
#                                        address  \
# 0   0x33c4f0043e2e988b3c2e9c77e2c670efe709bfe3
# 1   0xbb98b3d2b18aef63a3178023a920971cf5f29be4
# 2   0xeef1a9507b3d505f0062f2be9453981255b503c8
# 3   0xa4d8c89f0c20efbe54cba9e7e7a7e509056228d9
# 4   0xa189279260ff4f65b078379a4c7c2cb7e90934ac
# 5   0x129ff8de02ed70aac5a25de8d9acd3a5c1018acc
# 6   0x129ff8de02ed70aac5a25de8d9acd3a5c1018acc
# 7   0x307246a0284e5b927ef49718ea35aa0007b93186
# 8   0x00a59c2d0f0f4837028d47a391decbffc1e10608
# 9   0xa4d8c89f0c20efbe54cba9e7e7a7e509056228d9
# 10  0x129ff8de02ed70aac5a25de8d9acd3a5c1018acc
# 11  0x129ff8de02ed70aac5a25de8d9acd3a5c1018acc
#
#                                               tx_hash   blk_num   timestamp  \
# 0   0xca666c287f1e1f2e1f1e766290ce0193bbf50ae51e1e...  61391507  1725402143
# 1   0x7a01a24c29373cb01ff6ac20c5e21d4e3c8e592c1749...  61391507  1725402143
# 2   0x43ccc5e3205535ea03ace347c2b4cf1b0e89b4dda1b0...  61391508  1725402145
# 3   0x7760e06684606fe1ccae02b353e6645f15b0bbfa3dba...  61391508  1725402145
# 4   0x7abda0b7071af7696e2effc703c665375bb77f674ee2...  61391508  1725402145
# 5   0x37e64c072f4e0c43c55b71ea691ae9b8afb91ff8e90f...  61391510  1725402149
# 6   0x2037ebc07b9ae422bc9d25cce69b5e0abeb2b7b02224...  61391510  1725402149
# 7   0x6451a745eb6583272d3244b5fc690b8d461f8432d3c9...  61391510  1725402149
# 8   0x39aff3a1b41e82b5fc62d44d76c47143ffc940c6d554...  61391510  1725402149
# 9   0x98990115e4e7781138cbe85b50164ffd9d5a8d77d83b...  61391510  1725402149
# 10  0x4f61521a3082a52981e47632285aca29bf9e2fa89dd8...  61391510  1725402149
# 11  0x708b3c14f149738c7e113dad4b9cf4fed485e8690eb4...  61391510  1725402149
#
#                                               details
# 0   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 1   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 2   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 3   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 4   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 5   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 6   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 7   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 8   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 9   {'web3_type': <class 'web3._utils.datatypes.Sw...
# 10  {'web3_type': <class 'web3._utils.datatypes.Sw...
# 11  {'web3_type': <class 'web3._utils.datatypes.Sw...

# %%
dict_events
# Out:
# {0: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x33c4f0043e2e988b3c2e9c77e2c670efe709bfe3',
#   'tx_hash': '0xca666c287f1e1f2e1f1e766290ce0193bbf50ae51e1ee3dda21eba6931d13118',
#   'blk_num': 61391507,
#   'timestamp': 1725402143,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'token1': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'amount0': 67091744959784151036,
#    'amount1': -10986653099520994,
#    'sqrt_price_x96': 1013867763897557727523242570,
#    'liquidity': 10272917212262739854332,
#    'tick': -87176}},
#  1: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xbb98b3d2b18aef63a3178023a920971cf5f29be4',
#   'tx_hash': '0x7a01a24c29373cb01ff6ac20c5e21d4e3c8e592c17490cf1520b1e8250c63e1f',
#   'blk_num': 61391507,
#   'timestamp': 1725402143,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'token1': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'amount0': 42489993312417012,
#    'amount1': -104598032,
#    'sqrt_price_x96': 3931857631621130441193885,
#    'liquidity': 51852610810881057,
#    'tick': -198230}},
#  2: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xeef1a9507b3d505f0062f2be9453981255b503c8',
#   'tx_hash': '0x43ccc5e3205535ea03ace347c2b4cf1b0e89b4dda1b010e77662db956ca5eb7d',
#   'blk_num': 61391508,
#   'timestamp': 1725402145,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x40DBd3004a80a4D1dDa27776671720AE16890360',
#    'token1': '0xbfa1CBFc7B79115947889ac7Cb25801EE8055dF9',
#    'amount0': 337999,
#    'amount1': -195925061,
#    'sqrt_price_x96': 1907979247903587927429876889556,
#    'liquidity': 967099068992,
#    'tick': 63632}},
#  3: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xa4d8c89f0c20efbe54cba9e7e7a7e509056228d9',
#   'tx_hash': '0x7760e06684606fe1ccae02b353e6645f15b0bbfa3dba81d44177dddee005d23a',
#   'blk_num': 61391508,
#   'timestamp': 1725402145,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'token1': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'amount0': -131432992,
#    'amount1': 53397666811125700,
#    'sqrt_price_x96': 1596552075343416313534891893676848,
#    'liquidity': 181857149551968536,
#    'tick': 198230}},
#  4: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xa189279260ff4f65b078379a4c7c2cb7e90934ac',
#   'tx_hash': '0x7abda0b7071af7696e2effc703c665375bb77f674ee2d89f0de9a25657505b7b',
#   'blk_num': 61391508,
#   'timestamp': 1725402145,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x6E7c5a418DD1395068E539514B8c4Dc398a12e9e',
#    'token1': '0x26A0225e27227FA6b5eAd5B029532EC599C0a02e',
#    'amount0': 300000000000000000,
#    'amount1': -596693,
#    'sqrt_price_x96': 112288253918306534698090,
#    'liquidity': 2148450931774380,
#    'tick': -269349}},
#  5: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x129ff8de02ed70aac5a25de8d9acd3a5c1018acc',
#   'tx_hash': '0x37e64c072f4e0c43c55b71ea691ae9b8afb91ff8e90f134ec14a1eebd63509fd',
#   'blk_num': 61391510,
#   'timestamp': 1725402149,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x2f3EFba93D82B86C4ae9ABc21745aF2F44F76eEB',
#    'token1': '0x2f3EFba93D82B86C4ae9ABc21745aF2F44F76eEB',
#    'amount0': 14389365935519684055,
#    'amount1': -3428983,
#    'sqrt_price_x96': 38474037005671269685560,
#    'liquidity': 640113861865843,
#    'tick': -290772}},
#  6: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x129ff8de02ed70aac5a25de8d9acd3a5c1018acc',
#   'tx_hash': '0x2037ebc07b9ae422bc9d25cce69b5e0abeb2b7b02224750bcd44997b77ff38a3',
#   'blk_num': 61391510,
#   'timestamp': 1725402149,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x3cf7A3399439e3C10E2ea7e01272B54A66A04BA6',
#    'token1': '0x3cf7A3399439e3C10E2ea7e01272B54A66A04BA6',
#    'amount0': -6610114722570505684,
#    'amount1': 1567422,
#    'sqrt_price_x96': 38667942898762264622048,
#    'liquidity': 640113861865843,
#    'tick': -290672}},
#  7: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x307246a0284e5b927ef49718ea35aa0007b93186',
#   'tx_hash': '0x6451a745eb6583272d3244b5fc690b8d461f8432d3c9ef30449ee098a213da6e',
#   'blk_num': 61391510,
#   'timestamp': 1725402149,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x07964f135f276412b3182a3B2407b8dd45000000',
#    'token1': '0xa9368190380a1FB36EBc505490EAC560fE54dd73',
#    'amount0': -434804293765862029065,
#    'amount1': 199400000,
#    'sqrt_price_x96': 53411683633247170695524,
#    'liquidity': 284744580431052145,
#    'tick': -284211}},
#  8: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x00a59c2d0f0f4837028d47a391decbffc1e10608',
#   'tx_hash': '0x39aff3a1b41e82b5fc62d44d76c47143ffc940c6d554a0b69b04a379ca168095',
#   'blk_num': 61391510,
#   'timestamp': 1725402149,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x643770E279d5D0733F21d6DC03A8efbABf3255B4',
#    'token1': '0x643770E279d5D0733F21d6DC03A8efbABf3255B4',
#    'amount0': -1616797865874429654773,
#    'amount1': 253649107792882468718116864,
#    'sqrt_price_x96': 31379765345590495855474378211689,
#    'liquidity': 46076731336899012587871364217,
#    'tick': 119637}},
#  9: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0xa4d8c89f0c20efbe54cba9e7e7a7e509056228d9',
#   'tx_hash': '0x98990115e4e7781138cbe85b50164ffd9d5a8d77d83be2eca04582ff205d6e9e',
#   'blk_num': 61391510,
#   'timestamp': 1725402149,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'token1': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#    'amount0': -165227265,
#    'amount1': 67129571980447227,
#    'sqrt_price_x96': 1596581306492013754784066270264810,
#    'liquidity': 181857149551968536,
#    'tick': 198230}},
#  10: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x129ff8de02ed70aac5a25de8d9acd3a5c1018acc',
#   'tx_hash': '0x4f61521a3082a52981e47632285aca29bf9e2fa89dd8b5e8a07023ab54e0bd44',
#   'blk_num': 61391510,
#   'timestamp': 1725402149,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x0aF89E1620b96170e2a9D0b68fEebb767eD044c3',
#    'token1': '0x83e0f3dC98B095406D016f35d5244bF1f51fDa94',
#    'amount0': 14562389747778259782,
#    'amount1': -3428983,
#    'sqrt_price_x96': 38243530870579085680706,
#    'liquidity': 640113861865843,
#    'tick': -290892}},
#  11: {'chain': 'polygon',
#   'contract': 'uniswapv3pool',
#   'type': 'swap',
#   'platform': 'uniswap_v3',
#   'address': '0x129ff8de02ed70aac5a25de8d9acd3a5c1018acc',
#   'tx_hash': '0x708b3c14f149738c7e113dad4b9cf4fed485e8690eb4e5092e4464174fbc6530',
#   'blk_num': 61391510,
#   'timestamp': 1725402149,
#   'details': {'web3_type': web3._utils.datatypes.Swap,
#    'token0': '0x2f3EFba93D82B86C4ae9ABc21745aF2F44F76eEB',
#    'token1': '0x2f3EFba93D82B86C4ae9ABc21745aF2F44F76eEB',
#    'amount0': -14547908701408721510,
#    'amount1': 3428983,
#    'sqrt_price_x96': 38667730629810119291527,
#    'liquidity': 640113861865843,
#    'tick': -290672}}}

# %% [markdown]
# ### (3) Extract Burn Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 250

# %%
dict_events = rEvents.apply(EventType.BURN, start_block=start_block, end_block=last_block)
# Out:
# burn at block:61,391,265 tx:0xb0fccab49e1b38076d2bcb36f7cbb07fe06f3472de4fd1352afdf877ae78efa8
# burn at block:61,391,274 tx:0x38f65c4cdf3e821a5f77860a8d9ba115b613c7b769386b17d454fb1e33066844
# burn at block:61,391,287 tx:0x666627e33ec348af4498399ffa55e7263fd5c9bceec375297ba7fe13d9f525ff
# burn at block:61,391,319 tx:0x920dd3910132e3c1435998517969bfdab179028527df995bc166af1cd5bc93db
# burn at block:61,391,324 tx:0x00efe89df43370c2f872bb04c0b7421f9551c863f5fe8c7190d27fdce99cd9fb
# burn at block:61,391,381 tx:0x2431d4b91e12e7fce1613141badc8fff77be106e48f710defb5ff76dae97a4f0
# burn at block:61,391,381 tx:0x2431d4b91e12e7fce1613141badc8fff77be106e48f710defb5ff76dae97a4f0
# burn at block:61,391,391 tx:0x84e8a84717195d52d1b6265c3fb908450a4edba4ad7a6ed4a97e2c26fbe7ff85
# burn at block:61,391,391 tx:0x84e8a84717195d52d1b6265c3fb908450a4edba4ad7a6ed4a97e2c26fbe7ff85
# burn at block:61,391,402 tx:0xec6276d7d106d878969dc03f964829dcb9a8bc0618ed0409b54c74609646d5e4
# burn at block:61,391,402 tx:0xec6276d7d106d878969dc03f964829dcb9a8bc0618ed0409b54c74609646d5e4
# burn at block:61,391,407 tx:0x7476ecf4edc04e230e41fa9e8ae5d55ae0ddbc3a98ae5543083320664a5919a1
# burn at block:61,391,413 tx:0xac36ea084f7f7304b4dafa84f1637439c22fbe20c7e8f2574007a9acba7ed92c
# burn at block:61,391,453 tx:0xcf068046c818401ddd07fc8dd41fe5f14ea0a948f8e6a57a16610d7040dbfbea
# burn at block:61,391,467 tx:0x27a0c26fc2c3531a0f59a2942f37f37b81a68f3a9180ad760f4af668cbae7bb6
# burn at block:61,391,467 tx:0x27a0c26fc2c3531a0f59a2942f37f37b81a68f3a9180ad760f4af668cbae7bb6
# burn at block:61,391,467 tx:0x27a0c26fc2c3531a0f59a2942f37f37b81a68f3a9180ad760f4af668cbae7bb6
# burn at block:61,391,467 tx:0x27a0c26fc2c3531a0f59a2942f37f37b81a68f3a9180ad760f4af668cbae7bb6
# burn at block:61,391,483 tx:0xc8e55a57571cd2eb9734f40e3fe90780ed13e00a86362cd91c33e26df3c75a5f
# burn at block:61,391,484 tx:0x3e9218ffd918ab1df768e3e1892025a12bb671ada89b6f6a3fd0114e59339186
# burn at block:61,391,491 tx:0xb058860572ccada3b1650c1ab93139c2cc8a23ee2a6342a784a5b3b69a93485f
# burn at block:61,391,507 tx:0xabb307709d8ec92ae701fdc789a2776b8fc5909809a4d165861e3f38b128f652
# burn at block:61,391,511 tx:0x42de6adc91b539764ece67799140049d8386c53f6cc13314dee4c6641c5c389a
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#       chain       contract  type    platform  \
# 0   polygon  uniswapv3pool  burn  uniswap_v3
# 1   polygon  uniswapv3pool  burn  uniswap_v3
# 2   polygon  uniswapv3pool  burn  uniswap_v3
# 3   polygon  uniswapv3pool  burn  uniswap_v3
# 4   polygon  uniswapv3pool  burn  uniswap_v3
# 5   polygon  uniswapv3pool  burn  uniswap_v3
# 6   polygon  uniswapv3pool  burn  uniswap_v3
# 7   polygon  uniswapv3pool  burn  uniswap_v3
# 8   polygon  uniswapv3pool  burn  uniswap_v3
# 9   polygon  uniswapv3pool  burn  uniswap_v3
# 10  polygon  uniswapv3pool  burn  uniswap_v3
# 11  polygon  uniswapv3pool  burn  uniswap_v3
# 12  polygon  uniswapv3pool  burn  uniswap_v3
# 13  polygon  uniswapv3pool  burn  uniswap_v3
# 14  polygon  uniswapv3pool  burn  uniswap_v3
# 15  polygon  uniswapv3pool  burn  uniswap_v3
# 16  polygon  uniswapv3pool  burn  uniswap_v3
# 17  polygon  uniswapv3pool  burn  uniswap_v3
# 18  polygon  uniswapv3pool  burn  uniswap_v3
# 19  polygon  uniswapv3pool  burn  uniswap_v3
# 20  polygon  uniswapv3pool  burn  uniswap_v3
# 21  polygon  uniswapv3pool  burn  uniswap_v3
# 22  polygon  uniswapv3pool  burn  uniswap_v3
#
#                                        address  \
# 0   0xead1cd21ddf8793debc9484a0b8d286230c9b5a3
# 1   0xa4d8c89f0c20efbe54cba9e7e7a7e509056228d9
# 2   0xead1cd21ddf8793debc9484a0b8d286230c9b5a3
# 3   0xda71299ff6bdac31bdcafde52a41d460f17e3ad9
# 4   0xb6e57ed85c4c9dbfef2a68711e9d6f36c56e0fcb
# 5   0xda71299ff6bdac31bdcafde52a41d460f17e3ad9
# 6   0xda71299ff6bdac31bdcafde52a41d460f17e3ad9
# 7   0xda71299ff6bdac31bdcafde52a41d460f17e3ad9
# 8   0xda71299ff6bdac31bdcafde52a41d460f17e3ad9
# 9   0xda71299ff6bdac31bdcafde52a41d460f17e3ad9
# 10  0xda71299ff6bdac31bdcafde52a41d460f17e3ad9
# 11  0x167384319b41f7094e62f7506409eb38079abff8
# 12  0xf7c5f9b97815fbfcbeef672009ac14c7a51f03af
# 13  0xa374094527e1673a86de625aa59517c5de346d32
# 14  0xae81fac689a1b4b1e06e7ef4a2ab4cd8ac0a087d
# 15  0xae81fac689a1b4b1e06e7ef4a2ab4cd8ac0a087d
# 16  0xae81fac689a1b4b1e06e7ef4a2ab4cd8ac0a087d
# 17  0xae81fac689a1b4b1e06e7ef4a2ab4cd8ac0a087d
# 18  0xf7c5f9b97815fbfcbeef672009ac14c7a51f03af
# 19  0xde2d1fd2e8238aba80a5b80c7262e4833d92f624
# 20  0x019c29d5c97f8cbaa67013e2cf4b6506a5cf183a
# 21  0xf7c5f9b97815fbfcbeef672009ac14c7a51f03af
# 22  0x167384319b41f7094e62f7506409eb38079abff8
#
#                                               tx_hash   blk_num   timestamp  \
# 0   0xb0fccab49e1b38076d2bcb36f7cbb07fe06f3472de4f...  61391265  1725401627
# 1   0x38f65c4cdf3e821a5f77860a8d9ba115b613c7b76938...  61391274  1725401645
# 2   0x666627e33ec348af4498399ffa55e7263fd5c9bceec3...  61391287  1725401673
# 3   0x920dd3910132e3c1435998517969bfdab179028527df...  61391319  1725401741
# 4   0x00efe89df43370c2f872bb04c0b7421f9551c863f5fe...  61391324  1725401751
# 5   0x2431d4b91e12e7fce1613141badc8fff77be106e48f7...  61391381  1725401874
# 6   0x2431d4b91e12e7fce1613141badc8fff77be106e48f7...  61391381  1725401874
# 7   0x84e8a84717195d52d1b6265c3fb908450a4edba4ad7a...  61391391  1725401894
# 8   0x84e8a84717195d52d1b6265c3fb908450a4edba4ad7a...  61391391  1725401894
# 9   0xec6276d7d106d878969dc03f964829dcb9a8bc0618ed...  61391402  1725401918
# 10  0xec6276d7d106d878969dc03f964829dcb9a8bc0618ed...  61391402  1725401918
# 11  0x7476ecf4edc04e230e41fa9e8ae5d55ae0ddbc3a98ae...  61391407  1725401928
# 12  0xac36ea084f7f7304b4dafa84f1637439c22fbe20c7e8...  61391413  1725401942
# 13  0xcf068046c818401ddd07fc8dd41fe5f14ea0a948f8e6...  61391453  1725402026
# 14  0x27a0c26fc2c3531a0f59a2942f37f37b81a68f3a9180...  61391467  1725402056
# 15  0x27a0c26fc2c3531a0f59a2942f37f37b81a68f3a9180...  61391467  1725402056
# 16  0x27a0c26fc2c3531a0f59a2942f37f37b81a68f3a9180...  61391467  1725402056
# 17  0x27a0c26fc2c3531a0f59a2942f37f37b81a68f3a9180...  61391467  1725402056
# 18  0xc8e55a57571cd2eb9734f40e3fe90780ed13e00a8636...  61391483  1725402090
# 19  0x3e9218ffd918ab1df768e3e1892025a12bb671ada89b...  61391484  1725402092
# 20  0xb058860572ccada3b1650c1ab93139c2cc8a23ee2a63...  61391491  1725402109
# 21  0xabb307709d8ec92ae701fdc789a2776b8fc5909809a4...  61391507  1725402143
# 22  0x42de6adc91b539764ece67799140049d8386c53f6cc1...  61391511  1725402151
#
#                                               details
# 0   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 1   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 2   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 3   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 4   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 5   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 6   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 7   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 8   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 9   {'web3_type': <class 'web3._utils.datatypes.Bu...
# 10  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 11  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 12  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 13  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 14  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 15  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 16  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 17  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 18  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 19  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 20  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 21  {'web3_type': <class 'web3._utils.datatypes.Bu...
# 22  {'web3_type': <class 'web3._utils.datatypes.Bu...

# %% [markdown]
# ### (4) Create Events

# %%
time.sleep(2)

# %%
abi = ABILoad(Platform.UNIV3, JSONContract.UniswapV3Factory)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 5000

# %%
dict_events = rEvents.apply(EventType.CREATE, start_block=start_block, end_block=last_block)
# Out:
# create at block:61,386,834 tx:0xa41c907dedcee7d8e4f59ce53c3823aa6ec4e73fc15cf569d7a4ca3499b8a951
# create at block:61,388,160 tx:0x2b0a866363b4aabfe76f6c5e679e74aa8b61ce247c85a5679ea5d77051656be3
# create at block:61,388,525 tx:0x197ac382d39ce862d987979bbcc9a7533e64523e5c2818c76c3ca3ecac53b04e
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#      chain          contract         type    platform  \
# 0  polygon  uniswapv3factory  poolcreated  uniswap_v3
# 1  polygon  uniswapv3factory  poolcreated  uniswap_v3
# 2  polygon  uniswapv3factory  poolcreated  uniswap_v3
#
#                                       address  \
# 0  0x1f98431c8ad98523631ae4a59f267346ea31f984
# 1  0x1f98431c8ad98523631ae4a59f267346ea31f984
# 2  0x917933899c6a5f8e37f31e19f92cdbff7e8ff0e2
#
#                                              tx_hash   blk_num   timestamp  \
# 0  0xa41c907dedcee7d8e4f59ce53c3823aa6ec4e73fc15c...  61386834  1725391821
# 1  0x2b0a866363b4aabfe76f6c5e679e74aa8b61ce247c85...  61388160  1725394753
# 2  0x197ac382d39ce862d987979bbcc9a7533e64523e5c28...  61388525  1725395575
#
#                                              details
# 0  {'web3_type': <class 'web3._utils.datatypes.Po...
# 1  {'web3_type': <class 'web3._utils.datatypes.Po...
# 2  {'web3_type': <class 'web3._utils.datatypes.Po...
