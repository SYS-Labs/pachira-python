# %%
import json
import time
from pachira import *

# %%
abi = ABILoad(Platform.SUSHI, JSONContract.UniswapV2Pair)

# %% [markdown]
# ### (1) Extract Mint Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 100

# %%
dict_events = rEvents.apply(EventType.MINT, start_block=start_block, end_block=last_block)
# Out:
# mint at block:63,600,787 tx:0x94f1f8b29a8e0330e5ff9439de389613a2c9747c0b6bbfe5f55fe2ebcc5b9fc6
# mint at block:63,600,788 tx:0x1adadc91dc340135b67c5f61ae0b1cc7f3e6b765c9be80520c362e990135a978
# mint at block:63,600,788 tx:0x1adadc91dc340135b67c5f61ae0b1cc7f3e6b765c9be80520c362e990135a978
# mint at block:63,600,788 tx:0x1adadc91dc340135b67c5f61ae0b1cc7f3e6b765c9be80520c362e990135a978
# mint at block:63,600,790 tx:0x54c447391542bb9c2a38dc08469b45bd5aa74ffa32d0332ca9b0ec3866113685
# mint at block:63,600,793 tx:0x983dfcc69577ecac95ba79198c02cd86aa3cdf4eab598c8d8f63ff7e876d64bd
# mint at block:63,600,794 tx:0x61a39fc5e2e876f806a4c4f359f760ca74d466278f27907376064d7ccdb3af7e
# mint at block:63,600,794 tx:0x61a39fc5e2e876f806a4c4f359f760ca74d466278f27907376064d7ccdb3af7e
# mint at block:63,600,796 tx:0xaf6f496f4007e3c3edf15882e7cb3b8dfacea2469bcae4227ec51adf25a7ee93
# mint at block:63,600,796 tx:0xaf6f496f4007e3c3edf15882e7cb3b8dfacea2469bcae4227ec51adf25a7ee93
# mint at block:63,600,796 tx:0xaf6f496f4007e3c3edf15882e7cb3b8dfacea2469bcae4227ec51adf25a7ee93
# mint at block:63,600,796 tx:0xaf6f496f4007e3c3edf15882e7cb3b8dfacea2469bcae4227ec51adf25a7ee93
# mint at block:63,600,801 tx:0xd36e5b61f111f43e4b8b3a1f037c6007d22f8886cf3f79a4be0016e7946f1087
# mint at block:63,600,801 tx:0xd36e5b61f111f43e4b8b3a1f037c6007d22f8886cf3f79a4be0016e7946f1087
# mint at block:63,600,801 tx:0xd36e5b61f111f43e4b8b3a1f037c6007d22f8886cf3f79a4be0016e7946f1087
# mint at block:63,600,807 tx:0xbbb26b2d79acb71bf06fb9f9bf72385531dee69a5f46d0a9b4fb59700c245e6f
# mint at block:63,600,809 tx:0x25dad35bb86bb426fcbdf5924eb85353fb2a84d804c10876c4eabcbad73d6d9b
# mint at block:63,600,809 tx:0x25dad35bb86bb426fcbdf5924eb85353fb2a84d804c10876c4eabcbad73d6d9b
# mint at block:63,600,809 tx:0x25dad35bb86bb426fcbdf5924eb85353fb2a84d804c10876c4eabcbad73d6d9b
# mint at block:63,600,809 tx:0x25dad35bb86bb426fcbdf5924eb85353fb2a84d804c10876c4eabcbad73d6d9b
# mint at block:63,600,809 tx:0x823795bece67569d7c32ad2533f080ae61c3ace1e968ab8d8dc3bdf4c5279e99
# mint at block:63,600,809 tx:0x823795bece67569d7c32ad2533f080ae61c3ace1e968ab8d8dc3bdf4c5279e99
# mint at block:63,600,811 tx:0x2bb788eb6ff5da864c7a9622bea5d2b2b005135448ce6467996acd9a4ed30491
# mint at block:63,600,868 tx:0xa8ba47d5b7c95123d936d95ce9350d0225f85d327a8e57146b3c708e650507e1
# mint at block:63,600,871 tx:0x0c2fae0ef5e073fe1ff10669651f6af8145eb1028b534db5415986e628c04d21
# mint at block:63,600,876 tx:0x14aa8b814ed20216e2d09b09e085cba2fcd8863a17b634a8b44c9b1a9e8ad91a
# mint at block:63,600,876 tx:0x14aa8b814ed20216e2d09b09e085cba2fcd8863a17b634a8b44c9b1a9e8ad91a
# mint at block:63,600,876 tx:0x14aa8b814ed20216e2d09b09e085cba2fcd8863a17b634a8b44c9b1a9e8ad91a
# .

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
# Out:
#       chain       contract  type platform  \
# 0   polygon  uniswapv2pair  mint    sushi
# 1   polygon  uniswapv2pair  mint    sushi
# 2   polygon  uniswapv2pair  mint    sushi
# 3   polygon  uniswapv2pair  mint    sushi
# 4   polygon  uniswapv2pair  mint    sushi
# 5   polygon  uniswapv2pair  mint    sushi
# 6   polygon  uniswapv2pair  mint    sushi
# 7   polygon  uniswapv2pair  mint    sushi
# 8   polygon  uniswapv2pair  mint    sushi
# 9   polygon  uniswapv2pair  mint    sushi
# 10  polygon  uniswapv2pair  mint    sushi
# 11  polygon  uniswapv2pair  mint    sushi
# 12  polygon  uniswapv2pair  mint    sushi
# 13  polygon  uniswapv2pair  mint    sushi
# 14  polygon  uniswapv2pair  mint    sushi
# 15  polygon  uniswapv2pair  mint    sushi
# 16  polygon  uniswapv2pair  mint    sushi
# 17  polygon  uniswapv2pair  mint    sushi
# 18  polygon  uniswapv2pair  mint    sushi
# 19  polygon  uniswapv2pair  mint    sushi
# 20  polygon  uniswapv2pair  mint    sushi
# 21  polygon  uniswapv2pair  mint    sushi
# 22  polygon  uniswapv2pair  mint    sushi
# 23  polygon  uniswapv2pair  mint    sushi
# 24  polygon  uniswapv2pair  mint    sushi
# 25  polygon  uniswapv2pair  mint    sushi
# 26  polygon  uniswapv2pair  mint    sushi
# 27  polygon  uniswapv2pair  mint    sushi
# 28  polygon  uniswapv2pair  mint    sushi
# 29  polygon  uniswapv2pair  mint    sushi
# 30  polygon  uniswapv2pair  mint    sushi
# 31  polygon  uniswapv2pair  mint    sushi
# 32  polygon  uniswapv2pair  mint    sushi
# 33  polygon  uniswapv2pair  mint    sushi
# 34  polygon  uniswapv2pair  mint    sushi
# 35  polygon  uniswapv2pair  mint    sushi
# 36  polygon  uniswapv2pair  mint    sushi
# 37  polygon  uniswapv2pair  mint    sushi
# 38  polygon  uniswapv2pair  mint    sushi
# 39  polygon  uniswapv2pair  mint    sushi
# 40  polygon  uniswapv2pair  mint    sushi
# 41  polygon  uniswapv2pair  mint    sushi
# 42  polygon  uniswapv2pair  mint    sushi
# 43  polygon  uniswapv2pair  mint    sushi
# 44  polygon  uniswapv2pair  mint    sushi
# 45  polygon  uniswapv2pair  mint    sushi
# 46  polygon  uniswapv2pair  mint    sushi
# 47  polygon  uniswapv2pair  mint    sushi
# 48  polygon  uniswapv2pair  mint    sushi
# 49  polygon  uniswapv2pair  mint    sushi
# 50  polygon  uniswapv2pair  mint    sushi
# 51  polygon  uniswapv2pair  mint    sushi
# 52  polygon  uniswapv2pair  mint    sushi
#
#                                        address  \
# 0   0x9e621dcf9e5205d7ee5fbfdda6ae3a6a2de2a776
# 1   0x28424507fefb6f7f8e9d3860f56504e4e5f5f390
# 2   0x28424507fefb6f7f8e9d3860f56504e4e5f5f390
# 3   0x5c2ed810328349100a66b82b78a1791b101c9d61
# 4   0x9b39dbdf20517bdeed1f21233207ed6542b6fd08
# 5   0x9b39dbdf20517bdeed1f21233207ed6542b6fd08
# 6   0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 7   0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 8   0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 9   0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 10  0x28424507fefb6f7f8e9d3860f56504e4e5f5f390
# 11  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 12  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 13  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 14  0x28424507fefb6f7f8e9d3860f56504e4e5f5f390
# 15  0x41171356e89ecc68e2b468636e63667d396bff0f
# 16  0x27f8d03b3a2196956ed754badc28d73be8830a6e
# 17  0x27f8d03b3a2196956ed754badc28d73be8830a6e
# 18  0x5c2ed810328349100a66b82b78a1791b101c9d61
# 19  0x27f8d03b3a2196956ed754badc28d73be8830a6e
# 20  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 21  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 22  0x9b39dbdf20517bdeed1f21233207ed6542b6fd08
# 23  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 24  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 25  0x28424507fefb6f7f8e9d3860f56504e4e5f5f390
# 26  0x9e621dcf9e5205d7ee5fbfdda6ae3a6a2de2a776
# 27  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 28  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 29  0x9e621dcf9e5205d7ee5fbfdda6ae3a6a2de2a776
# 30  0x64958654412fccad8b46e68c49075bf6d64cdad7
# 31  0x41171356e89ecc68e2b468636e63667d396bff0f
# 32  0x9b39dbdf20517bdeed1f21233207ed6542b6fd08
# 33  0x5c2ed810328349100a66b82b78a1791b101c9d61
# 34  0x5c2ed810328349100a66b82b78a1791b101c9d61
# 35  0x28424507fefb6f7f8e9d3860f56504e4e5f5f390
# 36  0x41171356e89ecc68e2b468636e63667d396bff0f
# 37  0x9e621dcf9e5205d7ee5fbfdda6ae3a6a2de2a776
# 38  0x41171356e89ecc68e2b468636e63667d396bff0f
# 39  0x41171356e89ecc68e2b468636e63667d396bff0f
# 40  0x41171356e89ecc68e2b468636e63667d396bff0f
# 41  0x60d55f02a771d515e077c9c2403a1ef324885cec
# 42  0x9e621dcf9e5205d7ee5fbfdda6ae3a6a2de2a776
# 43  0x9b39dbdf20517bdeed1f21233207ed6542b6fd08
# 44  0x64958654412fccad8b46e68c49075bf6d64cdad7
# 45  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 46  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 47  0x28424507fefb6f7f8e9d3860f56504e4e5f5f390
# 48  0x1a13f4ca1d028320a707d99520abfefca3998b7f
# 49  0x41171356e89ecc68e2b468636e63667d396bff0f
# 50  0x5c2ed810328349100a66b82b78a1791b101c9d61
# 51  0x5c2ed810328349100a66b82b78a1791b101c9d61
# 52  0x28424507fefb6f7f8e9d3860f56504e4e5f5f390
#
#                                               tx_hash   blk_num   timestamp  \
# 0   0x94f1f8b29a8e0330e5ff9439de389613a2c9747c0b6b...  63600787  1730136745
# 1   0x1adadc91dc340135b67c5f61ae0b1cc7f3e6b765c9be...  63600788  1730136747
# 2   0x1adadc91dc340135b67c5f61ae0b1cc7f3e6b765c9be...  63600788  1730136747
# 36  0x6b402927a6a0dd46b46ec66e113dd560db50be80c005...  63600842  1730136861
# 37  0x3b45be0ab1a9d9f3d7728e46a3944809b5dddbdd2f77...  63600843  1730136863
# 38  0x641dce02211b2df15a5b57734a10e94cc1a6b78d1f42...  63600845  1730136867
# 39  0xac681f747df7aefb566050c75e686760e470ce3626a3...  63600848  1730136875
# 40  0x405ddf069b33f3e9ef5ac5aacc6a75fb7ecdca7906fa...  63600851  1730136881
# 41  0x032b10b49ad077ed908807ab0e77c5a30526aa6feef5...  63600857  1730136893
# 42  0x38a44df04fcb78bd731aa6c3a935ba28268ab84dd316...  63600863  1730136905
# 43  0x02e896b19c89d28920406dba7ff1289cc25cd2fb6490...  63600865  1730136911
# 44  0x9231457d1fbb5cb98880b89c5a4f664f8c75231cbc18...  63600866  1730136913
# 45  0xa8ba47d5b7c95123d936d95ce9350d0225f85d327a8e...  63600868  1730136917
# 46  0xa8ba47d5b7c95123d936d95ce9350d0225f85d327a8e...  63600868  1730136917
# 47  0xa8ba47d5b7c95123d936d95ce9350d0225f85d327a8e...  63600868  1730136917
# 48  0xa8ba47d5b7c95123d936d95ce9350d0225f85d327a8e...  63600868  1730136917
# 49  0x0c2fae0ef5e073fe1ff10669651f6af8145eb1028b53...  63600871  1730136923
# 50  0x14aa8b814ed20216e2d09b09e085cba2fcd8863a17b6...  63600876  1730136933
# 51  0x14aa8b814ed20216e2d09b09e085cba2fcd8863a17b6...  63600876  1730136933
# 52  0x14aa8b814ed20216e2d09b09e085cba2fcd8863a17b6...  63600876  1730136933
#
#                                               details
# 0   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 1   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 2   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 3   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 4   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 5   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 6   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 7   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 8   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 9   {'web3_type': <class 'web3._utils.datatypes.Mi...
# 10  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 11  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 12  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 13  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 14  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 15  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 16  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 17  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 18  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 19  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 20  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 21  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 22  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 23  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 24  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 25  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 26  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 27  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 28  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 29  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 30  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 31  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 32  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 33  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 34  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 35  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 36  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 37  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 38  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 39  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 40  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 41  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 42  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 43  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 44  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 45  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 46  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 47  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 48  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 49  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 50  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 51  {'web3_type': <class 'web3._utils.datatypes.Mi...
# 52  {'web3_type': <class 'web3._utils.datatypes.Mi...

# %% [markdown]
# ### (2) Extract Swap Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 3

# %%
dict_events = rEvents.apply(EventType.SWAP, start_block=start_block, end_block=last_block)

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events

# %%
dict_events

# %% [markdown]
# ### (3) Extract Burn Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 250

# %%
dict_events = rEvents.apply(EventType.BURN, start_block=start_block, end_block=last_block)

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events

# %% [markdown]
# ### (4) Extract Sync Events (Price Oracle)

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 10

# %%
dict_events = rEvents.apply(EventType.SYNC, start_block=start_block, end_block=last_block)

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events

# %% [markdown]
# ### (5) Extract Transfer Events

# %%
time.sleep(2)

# %%
connect = ConnectW3(Net.POLYGON)
connect.apply()

# %%
rEvents = RetrieveEvents(connect, abi)
last_block = rEvents.latest_block()
start_block = last_block - 5

# %%
dict_events = rEvents.apply(EventType.TRANSFER, start_block=start_block, end_block=last_block)

# %%
df_events = rEvents.to_dataframe(dict_events)
df_events
